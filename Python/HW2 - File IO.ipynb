# %%
# Python is able to easially parse ASCII files once you have a command of the basic python types
# To open a file for reading only
fp = open('afile.txt','r')
# The file pointer object has a few methods, usually you want to read the file and close it
lines = fp.readlines()
fp.close()
# Put this data into a numpy array and plot it. 
# Hint: look at string type, and investigate the methods it provides.

# %%
print lines
lines[0]
# Out:
# ['0.00000 0.00061 0.05569 0.00000 0.46969\n', '0.20408 0.00111 0.03109 0.20267 0.55989\n', '0.40816 0.00195 0.07246 0.39692 0.55919\n', '0.61224 0.00336 0.09702 0.57471 0.48936\n', '0.81633 0.00564 0.17389 0.72863 0.63101\n', '1.02041 0.00923 0.30288 0.85232 0.59115\n', '1.22449 0.01474 0.24374 0.94063 0.40369\n', '1.42857 0.02297 0.22240 0.98990 0.51659\n', '1.63265 0.03492 0.19272 0.99809 0.54804\n', '1.83673 0.05180 0.11959 0.96485 0.56174\n', '2.04082 0.07496 0.28899 0.89156 0.63902\n', '2.24490 0.10585 0.22896 0.78127 0.47902\n', '2.44898 0.14582 0.19692 0.63855 0.61787\n', '2.65306 0.19600 0.27584 0.46933 0.61476\n', '2.85714 0.25704 0.22905 0.28063 0.57523\n', '3.06122 0.32887 0.27719 0.08028 0.53170\n', '3.26531 0.41054 0.29472 -0.12340 0.52310\n', '3.46939 0.50001 0.46724 -0.32196 0.37376\n', '3.67347 0.59415 0.27710 -0.50715 0.68875\n', '3.87755 0.68884 0.32643 -0.67130 0.53343\n', '4.08163 0.77917 0.28405 -0.80758 0.44475\n', '4.28571 0.85989 0.43248 -0.91035 0.53052\n', '
# ...
